# %% [markdown]
# # Pandas Tutorials

# %% [markdown]
# ## Install libraries

# %%
pip install pandas

# %%
pip install numpy

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np

# %%
# object creation
s = pd.Series([1,3,5,7,8,9])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    8
# 5    9
# dtype: int64

# %%
# object creation
t = pd.Series([1,3,np.nan,5,7,8,9])
t
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3    5.0
# 4    7.0
# 5    8.0
# 6    9.0
# dtype: float64

# %%
# dates per day
dates = pd.date_range("20230101", periods=20)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(20,4), index =dates, columns= list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-01-01 -1.717280  0.383333 -1.465816  0.752935
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574 -0.371441 -1.601547 -0.077505
# 2023-01-06  0.387915  1.996464  0.990433 -0.122450
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-10  0.043323 -2.462685  2.046029 -0.278108
# 2023-01-11  0.923373 -0.596983 -0.032450 -0.230864
# 2023-01-12  0.702083 -0.705203 -0.199527  1.193155
# 2023-01-13  0.190716 -0.029701 -0.474885 -0.639056
# 2023-01-14 -0.769573  0.609692 -0.828558 -0.921701
# 2023-01-15 -1.777406  0.735288  0.572365 -0.965627
# 2023-01-16  0.250739 -0.524081  2.424349  1.184694
# 2023-01-17  0.140084 -0.479425 -1.068868 -1.298676
# ...

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20230101"),
        "C": pd.Series(1, index =list(range(4)), dtype ="float32"),
        "D": np.array([3]*4, dtype ="int32"),
        "E": pd.Categorical(["test","train","test","train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-01-01  1.0  3   test  foo
# 1  1.0 2023-01-01  1.0  3  train  foo
# 2  1.0 2023-01-01  1.0  3   test  foo
# 3  1.0 2023-01-01  1.0  3  train  foo

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20230101"),
        "C": pd.Series(1, index =list(range(4)), dtype ="float32"),
        "D": np.array([3]*4, dtype ="int32"),
        "E": pd.Categorical(["girl","women","girl","women"]),
        "F": "females",
    }
)
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2023-01-01  1.0  3   girl  females
# 1  1.0 2023-01-01  1.0  3  women  females
# 2  1.0 2023-01-01  1.0  3   girl  females
# 3  1.0 2023-01-01  1.0  3  women  females

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
# head means top columns informatiaon
df.head(2)
# Out:
#                    B         A         B         A
# 2023-01-01 -0.007585 -2.101851 -0.403640 -0.545252
# 2023-01-02 -1.760660 -0.165399 -0.587189 -0.423206

# %%
# tail means last wali information
df.tail(2)
# Out:
#                    B         A         B         A
# 2023-01-05  0.481866  0.969970 -0.253649  0.505211
# 2023-01-06  0.496779  0.336913 -1.992740 -0.053405

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[-0.22176421,  0.43437955, -0.63391552,  0.41020953],
#        [ 1.75020797, -0.0731517 , -0.83078921, -0.26648588],
#        [-2.06248565,  0.64741662,  0.65406242, -0.90317997],
#        [ 0.24930027, -0.08507967,  0.60551153, -0.21347408],
#        [ 1.23402136,  1.06436527,  1.26259371, -0.70725184],
#        [ 0.67985186,  0.48151708,  1.9209364 ,  0.03789381],
#        [-1.01755852,  0.7886034 ,  0.1510089 , -0.11890254],
#        [-1.20465476,  1.08320382, -0.20187727,  0.38393128],
#        [-1.71212066, -0.92425907, -0.57406414, -0.39672714],
#        [-0.43851676,  0.47231733, -0.40914925,  0.17268978],
#        [-1.04512094, -0.55266019,  1.21478565,  0.96237635],
#        [-1.40098276,  0.44419278,  0.50700022,  1.18673464],
#        [ 0.85614817,  0.70381624,  0.04851966,  0.41338456],
#        [ 1.06625129, -1.19722906,  0.80838134, -0.04680966],
#        [-0.71627515,  0.29699703, -0.02975348,  0.89333605],
# ...

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'women',
#         'females'],
#        [1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'women',
#         'females']], dtype=object)

# %%
df.describe()
# Out:
#                B          A          B          A
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0
# 2023-01-11   -0.230864
# 2023-01-12    1.193155
# 2023-01-13   -0.639056
# 2023-01-14   -0.921701
# 2023-01-15   -0.965627
# 2023-01-16    1.184694
# 2023-01-17   -1.298676
# 2023-01-18   -1.247698
# 2023-01-19    1.141653
# 2023-01-20    0.637043
# Freq: D, Name: D, dtype: float64

# %%
df["B"]
# Out:
# 2023-01-01    0.383333
# 2023-01-02    0.121100
# 2023-01-03   -1.142665
# 2023-01-04    0.734382
# 2023-01-05   -0.371441
# 2023-01-06    1.996464
# 2023-01-07    0.918510
# 2023-01-08    0.459953
# 2023-01-09    0.433012
# 2023-01-10   -2.462685
# 2023-01-11   -0.596983
# 2023-01-12   -0.705203
# 2023-01-13   -0.029701
# 2023-01-14    0.609692
# 2023-01-15    0.735288
# 2023-01-16   -0.524081
# 2023-01-17   -0.479425
# 2023-01-18   -0.037072
# 2023-01-19    0.600566
# 2023-01-20   -0.170542
# Freq: D, Name: B, dtype: float64

# %%
#row wise selection
df[0:3]
# Out:
#                    A         B         C         D
# 2023-01-01 -1.717280  0.383333 -1.465816  0.752935
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801

# %%
df[0:]
# Out:
#                    A         B         C         D
# 2023-01-01 -1.717280  0.383333 -1.465816  0.752935
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574 -0.371441 -1.601547 -0.077505
# 2023-01-06  0.387915  1.996464  0.990433 -0.122450
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-10  0.043323 -2.462685  2.046029 -0.278108
# 2023-01-11  0.923373 -0.596983 -0.032450 -0.230864
# 2023-01-12  0.702083 -0.705203 -0.199527  1.193155
# 2023-01-13  0.190716 -0.029701 -0.474885 -0.639056
# 2023-01-14 -0.769573  0.609692 -0.828558 -0.921701
# 2023-01-15 -1.777406  0.735288  0.572365 -0.965627
# 2023-01-16  0.250739 -0.524081  2.424349  1.184694
# 2023-01-17  0.140084 -0.479425 -1.068868 -1.298676
# ...

# %%
df[0:1]
# Out:
#                   A         B         C         D
# 2023-01-01 -1.71728  0.383333 -1.465816  0.752935

# %%
df[0:4]
# Out:
#                    A         B         C         D
# 2023-01-01 -1.717280  0.383333 -1.465816  0.752935
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306

# %%
df[1:10]
# Out:
#                    A         B         C         D
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574 -0.371441 -1.601547 -0.077505
# 2023-01-06  0.387915  1.996464  0.990433 -0.122450
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-10  0.043323 -2.462685  2.046029 -0.278108

# %%
#column wise selection
df.loc[dates[0]]
# Out:
# A   -1.717280
# B    0.383333
# C   -1.465816
# D    0.752935
# Name: 2023-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[2]]
# Out:
# A    0.288758
# B   -1.142665
# C    1.031405
# D    0.686801
# Name: 2023-01-03 00:00:00, dtype: float64

# %%
df.loc[:, ["A","B"]]
# Out:
#                    A         B
# 2023-01-01 -1.717280  0.383333
# 2023-01-02  0.433258  0.121100
# 2023-01-03  0.288758 -1.142665
# 2023-01-04  0.014780  0.734382
# 2023-01-05  0.144574 -0.371441
# 2023-01-06  0.387915  1.996464
# 2023-01-07  0.673246  0.918510
# 2023-01-08  0.595742  0.459953
# 2023-01-09  0.761121  0.433012
# 2023-01-10  0.043323 -2.462685
# 2023-01-11  0.923373 -0.596983
# 2023-01-12  0.702083 -0.705203
# 2023-01-13  0.190716 -0.029701
# 2023-01-14 -0.769573  0.609692
# 2023-01-15 -1.777406  0.735288
# 2023-01-16  0.250739 -0.524081
# 2023-01-17  0.140084 -0.479425
# 2023-01-18  0.610089 -0.037072
# 2023-01-19  0.424443  0.600566
# 2023-01-20 -1.240178 -0.170542

# %%
df.loc[:,["C","D"]]
# Out:
#                    C         D
# 2023-01-01 -1.465816  0.752935
# 2023-01-02 -1.137476  0.894932
# 2023-01-03  1.031405  0.686801
# 2023-01-04  1.887436  0.115306
# 2023-01-05 -1.601547 -0.077505
# 2023-01-06  0.990433 -0.122450
# 2023-01-07  0.437041  0.148386
# 2023-01-08 -1.349574  0.349012
# 2023-01-09  0.546483  0.203048
# 2023-01-10  2.046029 -0.278108
# 2023-01-11 -0.032450 -0.230864
# 2023-01-12 -0.199527  1.193155
# 2023-01-13 -0.474885 -0.639056
# 2023-01-14 -0.828558 -0.921701
# 2023-01-15  0.572365 -0.965627
# 2023-01-16  2.424349  1.184694
# 2023-01-17 -1.068868 -1.298676
# 2023-01-18 -1.289696 -1.247698
# 2023-01-19 -0.413613  1.141653
# 2023-01-20  1.145650  0.637043

# %%
df.loc["20230102":"20230104",["A","B"]]
# Out:
#                    A         B
# 2023-01-02  0.433258  0.121100
# 2023-01-03  0.288758 -1.142665
# 2023-01-04  0.014780  0.734382

# %%
df.loc[["20230102","20230104"],["A","B"]]
# Out:
#                    A         B
# 2023-01-02  0.433258  0.121100
# 2023-01-04  0.014780  0.734382

# %%
df.loc["20230110",["A","B","C"]]
# Out:
# A    0.043323
# B   -2.462685
# C    2.046029
# Name: 2023-01-10 00:00:00, dtype: float64

# %%
df.at[dates[0],"A"]
# Out:
# -1.7172801722202717

# %%
df.at[dates[10],"A"]
# Out:
# 0.9233728106537297

# %%
#position value
df.iloc[3]
# Out:
# A    0.014780
# B    0.734382
# C    1.887436
# D    0.115306
# Name: 2023-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:10]
# Out:
#                    A         B         C         D
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574 -0.371441 -1.601547 -0.077505
# 2023-01-06  0.387915  1.996464  0.990433 -0.122450
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-10  0.043323 -2.462685  2.046029 -0.278108

# %%
df.iloc[0:5, 10:15]
# Out:
# Empty DataFrame
# Columns: []
# Index: [2023-01-01 00:00:00, 2023-01-02 00:00:00, 2023-01-03 00:00:00, 2023-01-04 00:00:00, 2023-01-05 00:00:00]

# %%
# in[] left side is always row in between comma and then on the right side its the column
df.iloc[0:5, 0:3]
# Out:
#                    A         B         C
# 2023-01-01 -1.717280  0.383333 -1.465816
# 2023-01-02  0.433258  0.121100 -1.137476
# 2023-01-03  0.288758 -1.142665  1.031405
# 2023-01-04  0.014780  0.734382  1.887436
# 2023-01-05  0.144574 -0.371441 -1.601547

# %%
# this will select automatically all columns
df.iloc[0:5, :]
# Out:
#                    A         B         C         D
# 2023-01-01 -1.717280  0.383333 -1.465816  0.752935
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574 -0.371441 -1.601547 -0.077505

# %%
# this will select all rows
df.iloc[: , 0:2]
# Out:
#                    A         B
# 2023-01-01 -1.717280  0.383333
# 2023-01-02  0.433258  0.121100
# 2023-01-03  0.288758 -1.142665
# 2023-01-04  0.014780  0.734382
# 2023-01-05  0.144574 -0.371441
# 2023-01-06  0.387915  1.996464
# 2023-01-07  0.673246  0.918510
# 2023-01-08  0.595742  0.459953
# 2023-01-09  0.761121  0.433012
# 2023-01-10  0.043323 -2.462685
# 2023-01-11  0.923373 -0.596983
# 2023-01-12  0.702083 -0.705203
# 2023-01-13  0.190716 -0.029701
# 2023-01-14 -0.769573  0.609692
# 2023-01-15 -1.777406  0.735288
# 2023-01-16  0.250739 -0.524081
# 2023-01-17  0.140084 -0.479425
# 2023-01-18  0.610089 -0.037072
# 2023-01-19  0.424443  0.600566
# 2023-01-20 -1.240178 -0.170542

# %%
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-03  0.288758 -1.142665  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574 -0.371441 -1.601547 -0.077505
# 2023-01-06  0.387915  1.996464  0.990433 -0.122450
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-10  0.043323 -2.462685  2.046029 -0.278108
# 2023-01-11  0.923373 -0.596983 -0.032450 -0.230864
# 2023-01-12  0.702083 -0.705203 -0.199527  1.193155
# 2023-01-13  0.190716 -0.029701 -0.474885 -0.639056
# 2023-01-16  0.250739 -0.524081  2.424349  1.184694
# 2023-01-17  0.140084 -0.479425 -1.068868 -1.298676
# 2023-01-18  0.610089 -0.037072 -1.289696 -1.247698
# 2023-01-19  0.424443  0.600566 -0.413613  1.141653

# %%
df[df["A"]> 0.5]
# Out:
#                    A         B         C         D
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-11  0.923373 -0.596983 -0.032450 -0.230864
# 2023-01-12  0.702083 -0.705203 -0.199527  1.193155
# 2023-01-18  0.610089 -0.037072 -1.289696 -1.247698

# %%
df[df["B"] > 0]
# Out:
#                    A         B         C         D
# 2023-01-01 -1.717280  0.383333 -1.465816  0.752935
# 2023-01-02  0.433258  0.121100 -1.137476  0.894932
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-06  0.387915  1.996464  0.990433 -0.122450
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953 -1.349574  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-14 -0.769573  0.609692 -0.828558 -0.921701
# 2023-01-15 -1.777406  0.735288  0.572365 -0.965627
# 2023-01-19  0.424443  0.600566 -0.413613  1.141653

# %%
df[df >0]
# Out:
#                    A         B         C         D
# 2023-01-01       NaN  0.383333       NaN  0.752935
# 2023-01-02  0.433258  0.121100       NaN  0.894932
# 2023-01-03  0.288758       NaN  1.031405  0.686801
# 2023-01-04  0.014780  0.734382  1.887436  0.115306
# 2023-01-05  0.144574       NaN       NaN       NaN
# 2023-01-06  0.387915  1.996464  0.990433       NaN
# 2023-01-07  0.673246  0.918510  0.437041  0.148386
# 2023-01-08  0.595742  0.459953       NaN  0.349012
# 2023-01-09  0.761121  0.433012  0.546483  0.203048
# 2023-01-10  0.043323       NaN  2.046029       NaN
# 2023-01-11  0.923373       NaN       NaN       NaN
# 2023-01-12  0.702083       NaN       NaN  1.193155
# 2023-01-13  0.190716       NaN       NaN       NaN
# 2023-01-14       NaN  0.609692       NaN       NaN
# 2023-01-15       NaN  0.735288  0.572365       NaN
# 2023-01-16  0.250739       NaN  2.424349  1.184694
# 2023-01-17  0.140084       NaN       NaN       NaN
# ...

# %%
df2 = df.copy()

# %%
df2["E"]= ["one", "one", "two", "two","three","four","four",
"one", "one", "two", "two","three","four","four",
"one", "one", "two", "two","three","four"
]

# %%
df2["mean"]= [df2["B"] + 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df2["mean"]= [df2["B"] + 1]
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
# ...

# %%
df2["mean"]= [1.2,2.2,3.3,4.4,2.5,
1.2,2.2,3.3,4.4,2.5,
1.2,2.2,3.3,4.4,2.5,
1.2,2.2,3.3,4.4,2.5]

# %%
df2["new"]= [1.2,2.2,3.3,4.4,2.5,
1.2,2.2,3.3,4.4,2.5,
1.2,2.2,3.3,4.4,2.5,
1.2,2.2,3.3,4.4,2.5]

# %%
df2 = df2.iloc[:, 1:4]

# %%
df2
# Out:
#                    B         C         D
# 2023-01-01  0.383333 -1.465816  0.752935
# 2023-01-02  0.121100 -1.137476  0.894932
# 2023-01-03 -1.142665  1.031405  0.686801
# 2023-01-04  0.734382  1.887436  0.115306
# 2023-01-05 -0.371441 -1.601547 -0.077505
# 2023-01-06  1.996464  0.990433 -0.122450
# 2023-01-07  0.918510  0.437041  0.148386
# 2023-01-08  0.459953 -1.349574  0.349012
# 2023-01-09  0.433012  0.546483  0.203048
# 2023-01-10 -2.462685  2.046029 -0.278108
# 2023-01-11 -0.596983 -0.032450 -0.230864
# 2023-01-12 -0.705203 -0.199527  1.193155
# 2023-01-13 -0.029701 -0.474885 -0.639056
# 2023-01-14  0.609692 -0.828558 -0.921701
# 2023-01-15  0.735288  0.572365 -0.965627
# 2023-01-16 -0.524081  2.424349  1.184694
# 2023-01-17 -0.479425 -1.068868 -1.298676
# 2023-01-18 -0.037072 -1.289696 -1.247698
# 2023-01-19  0.600566 -0.413613  1.141653
# 2023-01-20 -0.170542  1.145650  0.637043
